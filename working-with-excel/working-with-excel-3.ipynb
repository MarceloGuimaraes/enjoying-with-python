# %%
import pandas as pd

# %%
df = pd.read_excel('01_SURF_Map_PerfilxEtapas_Alter_Vigencia_v03.xlsx',sheet_name=1,usecols=3)

# %%
df.head()
# Out:
#      Perfil Etapa Atual  Ação na solicitação               Próxima Etapa
# 0    CANAIS           -                  NaN   BPO - VALIDAR SOLICITAÇÃO
# 1  REGIONAL           -                  NaN   BPO - VALIDAR SOLICITAÇÃO
# 2    ADM OI           -                  NaN   BPO - VALIDAR SOLICITAÇÃO
# 3   ADM BPO           -                  NaN   BPO - VALIDAR SOLICITAÇÃO
# 4   ADM BPO           -                  NaN  BPO - ANEXAR TERMO ADITIVO

# %%
#removendo a coluna
del df['Ação na solicitação']

# %%
df.head()
# Out:
#      Perfil Etapa Atual               Próxima Etapa
# 0  CANAIS    -           BPO - VALIDAR SOLICITAÇÃO
# 1  REGIONAL  -           BPO - VALIDAR SOLICITAÇÃO
# 2  ADM OI    -           BPO - VALIDAR SOLICITAÇÃO
# 3  ADM BPO   -           BPO - VALIDAR SOLICITAÇÃO
# 4  ADM BPO   -           BPO - ANEXAR TERMO ADITIVO

# %%
df.loc[:]
# Out:
#       Perfil                                      Etapa Atual  \
# 0     CANAIS                                                -
# 1   REGIONAL                                                -
# 2     ADM OI                                                -
# 3    ADM BPO                                                -
# 4    ADM BPO                                                -
# 5    ADM BPO                        BPO - VALIDAR SOLICITAÇÃO
# 6    ADM BPO                       BPO - CANCELAR SOLICITAÇÃO
# 7    ADM BPO                        BPO - VALIDAR SOLICITAÇÃO
# 8     ADM OI                     ADM OI - AJUSTAR SOLICITAÇÃO
# 9     ADM OI                     ADM OI - AJUSTAR SOLICITAÇÃO
# 10   ADM BPO                        BPO - VALIDAR SOLICITAÇÃO
# 11  REGIONAL                        REG - AJUSTAR SOLICITAÇÃO
# 12  REGIONAL                        REG - AJUSTAR SOLICITAÇÃO
# 13   ADM BPO                        BPO - VALIDAR SOLICITAÇÃO
# ...

# %%
df['Perfil'].count()
# Out:
# 57
